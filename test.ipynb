# %%
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="all_barang"
)

mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM )
  # mycursor.execute("SELECT * FROM componenttable WHERE email='dgerbi11@answers.com'")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)

id = myresult[0][0]


myresult
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # all barang

# %%
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="all_barang"
)

mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM barang")
  # mycursor.execute("SELECT * FROM componenttable WHERE email='dgerbi11@answers.com'")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)

id = myresult[0][0]


myresult
# Out:
# ('GI0000000', 'Kran BCP Flexible 205 B-5 1/2 A13 MEMU2/PJ', 0, 92500.0, 0.0, 'K0005')
# ('GI0000001', 'Kran BCP Flexible - 1/2 A12 KMU3/MA ', 0, 160000.0, 0.0, 'K0005')
# ('GI0000002', 'Kran BCP Flexible 205QI 1/2 A10 MEMU2/PJ   ', 0, 92500.0, 0.0, 'K0005')
# ('GI0000003', 'Kran BCP - 1/2 A11 TRU4/PJ ', 0, 195000.0, 0.0, 'K0005')
# ('GI0000004', 'Kran BCP Precio 1/2 A35 CDMU2/PJ ', 0, 155000.0, 0.0, 'K0005')
# ('GI0000005', 'Kran BCP Flexible 205 II 1/2 A38 MEMU2/PJ', 0, 92500.0, 0.0, 'K0005')
# ('GI0000006', 'Kran BCP Flexible Pill Carlo 1008-1007 1/2 A19 DMU3/MA ', 0, 130000.0, 0.0, 'K0005')
# ('GI0000007', 'Kran BCP TY3955 1/2 A18  DEMU2/PJ', 0, 130000.0, 0.0, 'K0005')
# ('GI0000008', 'Kran BCP GZR 902 1/2 A17 MDMU2/AW ', 0, 78500.0, 0.0, 'K0005')
# ('GI0000009', 'Kran BCP Flexible SANITARY 1/2 A16 AMU3/PJ ', 0, 110000.0, 0.0, 'K0005')
# ('GI0000010', 'Kran BCP PLASTIK DOLPHIN 1/2 A15 EEMU2/PJ', 0, 37500.0, 0.0, 'K0005')
# ('GI0000011', 'Kran BCP 7225 - A14 RU4/PJ ', 0, 52500.0, 0.0, 'K0005')
# ('GI0000012', 'Kran BCP CIAO 1/2 A20 AMU3 ', 0, 110000.0, 0.0, 'K0005')
# ('GI0000013', 'Kran BCP BANDINI 042 1/2 A21 DRMU2/SSA ', 0, 117500.0, 0.0, 'K0005')
# ('GI0000014', 'Kran BCP 217 H2 1/2 A22 AMU3/AW', 0, 115000.0, 0.0, 'K0005')
# ('GI0000015', 'Kran BCP FLEXIBLE HTC 1/2 A23 MDMU2/AW ', 0, 87500.0, 0.0, 'K0005')
# ('GI0000016', 'Kran BCP FLEXIBLE 217 H2 1/2 A24 AMU3/AW ', 0, 115000.0, 0.0, 'K0005')
# ('GI0000017', 'Kran BCP FLEXIBLE HTC 1/2 A25 MDMU2/AW ', 0, 195000.0, 0.0, 'K0005')
# ('GI0000018', 'Kran BCP BRA210 8300 1/2 A31 IDMU2/PJ ', 0, 85000.0, 0.0, 'K0005')
# ('GI0000019', 'Kran BCP ESTONIA 1/2 A30 RMU3/MA ', 0, 57500.0, 0.0, 'K0005')
# ('GI0000020', 'Kran BCP FLEXIBLE GIO 3 1/2 A29 IDMU2/AW ', 0, 85000.0, 0.0, 'K0005')
# ('GI0000021', 'Kran BCP ARMIRAGE 1/2 A28 TTU4 ', 0, 180000.0, 0.0, 'K0005')
# ('GI0000022', 'Kran BCP FLEXIBLE G201 1/2 A27 AMU3/PJ ', 0, 115000.0, 0.0, 'K0005')
# ('GI0000023', 'Kran BCP FLEXIBLE SILFRA WL-02 1/2 A26 COMU2/MA', 0, 137500.0, 0.0, 'K0005')
# ('GI0000024', 'Kran BCP FLEXIBLE - 1/2 A32 AMU3/PJ', 0, 115000.0, 0.0, 'K0005')
# ('GI0000025', 'Kran BCP FLEXIBLE G203 1/2 A33 AMU3/PJ ', 0, 115000.0, 0.0, 'K0005')
# ('GI0000026', 'Kran BCP GZR 1/2 A34 REMU2/AW ', 0, 55000.0, 0.0, 'K0005')
# ('GI0000027', 'Kran BCP FLEXIBLE 207 J 1/2 A18A DMU3/AW ', 0, 125000.0, 0.0, 'K0005')
# ('GI0000028', 'Kran BCP FLEXIBLE HSG 503 1/2 A36 AMU3/AW', 0, 115000.0, 0.0, 'K0005')
# ('GI0000029', 'Kran BCP SKL 1/2 A37 KOMU2/MA ', 0, 165000.0, 0.0, 'K0005')
# ('GI0000030', 'Kran BCP WASSER TL-050 1/2 WS35 -', 0, 256000.0, 0.0, 'K0005')
# ('GI0000031', 'Kran BCP WASSER TC-050B 1/2 WS32 - ', 0, 282000.0, 0.0, 'K0005')
# ('GI0000032', 'Kran BCP DUPON Y6732-NC 1/2 DP15 -', 0, 240000.0, 0.0, 'K0005')
# ('GI0000033', 'Kran BCP DUPON 818-NC 1/2 DP13 -', 0, 341000.0, 0.0, 'K0005')
# ('GI0000034', 'Kran BCP DUPON B823-NC 1/2 DP11 -', 0, 388800.0, 0.0, 'K0005')
# ('GI0000035', 'Kran BCP ONDA N 868TG 1/2 ON8 -', 0, 266000.0, 0.0, 'K0005')
# ('GI0000036', 'Kran BCP ONDA H 868PJ 1/2 ON9 - ', 0, 276000.0, 0.0, 'K0005')
# ('GI0000037', 'Kran BCP FLEXIBLE WASSER TB-041F 1/2 - -', 0, 340000.0, 0.0, 'K0005')
# ('GI0000038', 'Kran BCP WASSER TB-040 1/2 - - ', 0, 320000.0, 0.0, 'K0005')
# ('GI0000039', 'Kran BCP WASSER TL3-040 1/2 - -', 0, 338000.0, 0.0, 'K0005')
# ('GI0000040', 'Kran BCP WASSER TC2 -040 1/2 - - ', 0, 359000.0, 0.0, 'K0005')
# ('GI0000041', 'Kran BCP WASSER TL2-040 1/2 - - ', 0, 349000.0, 0.0, 'K0005')
# ('GI0000042', 'Kran BCP WASSER TC2-055 1/2 - - ', 0, 359000.0, 0.0, 'K0005')
# ('GI0000043', 'Kran BCP WASSER TC-040 1/2 WS36 - ', 0, 342000.0, 0.0, 'K0005')
# ('GI0000044', 'Kran BCP WASSER TL-040 1/2 WS38 -', 0, 332000.0, 0.0, 'K0005')
# ('GI0000045', 'Kran Tembok Sobar 3/4 no 1 Tomu2 /Aw ', 0, 37500.0, 0.0, 'K0004')
# ('GI0000046', 'Kran Tembok MAVE 3/4 No 2 Tamu 2/Sh', 0, 35000.0, 0.0, 'K0004')
# ('GI0000047', 'Kran Tembok TAHO CRISTAL 3/4 No 3 TOMU2 ', 0, 36000.0, 0.0, 'K0004')
# ('GI0000048', 'Kran Tembok 88334 3/4 No 4 TOU3/JH', 0, 28000.0, 0.0, 'K0004')
# ('GI0000049', 'Kran Tembok MAVE 3/4 No 5 TAMU2 ', 0, 35000.0, 0.0, 'K0004')
# ('GI0000050', 'Kran Tembok MAVE Baling 3/4 No 6 EU4/SH', 0, 45000.0, 0.0, 'K0004')
# ('GI0000051', 'Kran Tembok MAHKOTA 3833c 3/4 no 7 TOU3/SH ', 0, 38000.0, 0.0, 'K0004')
# ('GI0000052', 'Kran Tembok 8833 3/4 No 8 TOU3/JH', 0, 38000.0, 0.0, 'K0004')
# ('GI0000053', 'Kran Tembok SKL 3/4 No 10 E143/PJ', 0, 36000.0, 0.0, 'K0004')
# ('GI0000054', 'Kran Tembok Sobar 3/4 No 12 TOMU2/AW', 0, 37500.0, 0.0, 'K0004')
# ('GI0000055', 'Kran Tembok DUPON 3/4 No DP7 TROKO', 0, 20000.0, 0.0, 'K0004')
# ('GI0000056', 'Kran Tembok MAVE 3/4 No 14 TOMU2/JH', 0, 35000.0, 0.0, 'K0004')
# ('GI0000057', 'Kran Tembok RIO BUNGA 3/4 No 15 EEMMU ', 0, 45000.0, 0.0, 'K0004')
# ('GI0000058', 'Kran Tembok RIO 3/4 No 16 EIU/SSA', 0, 40000.0, 0.0, 'K0004')
# ('GI0000059', 'Kran Double Fiorentino 1/2 No 27 EUMU2/PJ', 0, 40000.0, 0.0, 'K0004')
# ('GI0000060', 'Kran Double 1/2 No 37 DEMU2 ', 0, 110000.0, 0.0, 'K0004')
# ('GI0000061', 'Kran Double PIN Star 1/2 No 59 MMU3/PJ', 0, 95000.0, 0.0, 'K0004')
# ('GI0000062', 'Kran Double 223- P330 1/2 No 25 RDMU2  ', 0, 65000.0, 0.0, 'K0004')
# ('GI0000063', 'Kran Double FIO 1/2 No 26 MRMU2/PJ', 0, 95000.0, 0.0, 'K0004')
# ('GI0000064', 'Kran Double DB 1317 1/2 No 59A MU4/PJ', 0, 87500.0, 0.0, 'K0004')
# ('GI0000065', 'Kran Double TY 22 1/2 No 60 MU4/PJ', 0, 87500.0, 0.0, 'K0004')
# ('GI0000066', 'Kran Double 223-117 1/2 No 61 ROMU2', 0, 67500.0, 0.0, 'K0004')
# ('GI0000067', 'Kran Tembok ICO 1/2 No 26A TKU3  ', 0, 32500.0, 0.0, 'K0004')
# ('GI0000068', 'Kran Tembok 1015-1 1/2 No 25A EEU3/PJ ', 0, 37500.0, 0.0, 'K0004')
# ('GI0000069', 'Kran Tembok  DUPON 1/2 DP24 TRKU2', 0, 20000.0, 0.0, 'K0004')
# ('GI0000070', 'Kran Tembok MORSE 8135 1/2 No 38 IMU3', 0, 70000.0, 0.0, 'K0004')
# ('GI0000071', 'Kran Tembok  MINIMALIS 1/2 No 17 AMU3 ', 0, 110000.0, 0.0, 'K0004')
# ('GI0000072', 'Kran Tembok WD - C295 1/2 No 35 EAU3/PJ', 0, 45000.0, 0.0, 'K0004')
# ('GI0000073', 'Kran Tembok Fiorentino AF 826 L 1/2 No 67 AU4/MA ', 0, 105000.0, 0.0, 'K0004')
# ('GI0000074', 'Kran Tembok Fiorentino AM003 1/2 10MU2/MA No 34 ', 0, 68000.0, 0.0, 'K0004')
# ('GI0000075', 'Kran Tembok  4557 1/2 No 44 ERMU2/PJ', 0, 42500.0, 0.0, 'K0004')
# ('GI0000076', 'Kran Tembok RIO 1/2 No 20 TOMU2/JH', 0, 35000.0, 0.0, 'K0004')
# ('GI0000077', 'Kran Tembok ICO TM81 1/2 No 47 EMU3', 0, 42500.0, 0.0, 'K0004')
# ('GI0000078', 'Kran Tembok PUll Carlo 1/2 No 72 EEMU2', 0, 35000.0, 0.0, 'K0004')
# ('GI0000079', 'Kran Tembok ICO TM 5020 1/2 No 55 EMU3/PJ', 0, 42500.0, 0.0, 'K0004')
# ('GI0000080', 'Kran Tembok 133 P 330 1/2 No 21 EU41/PJ', 0, 37500.0, 0.0, 'K0004')
# ('GI0000081', 'Kran Tembok CROS 101 1/2 No 57 ETU3/PJ', 0, 37500.0, 0.0, 'K0004')
# ('GI0000082', 'Kran Tembok PIN STAR 1/2 No 63 EDMU2/PJ', 0, 47500.0, 0.0, 'K0004')
# ('GI0000083', 'Kran Shower AS 303 1/2 No 70 EU4/AS', 0, 32500.0, 0.0, 'K0004')
# ('GI0000084', 'Kran Shower Silver Star 1/2 No 31 EMU3', 0, 45000.0, 0.0, 'K0004')
# ('GI0000085', 'Kran Shower Strek 1/2 No 54 TRMU2/MA', 0, 27500.0, 0.0, 'K0004')
# ('GI0000086', 'Kran Shower DUPON 1/2 DP 63 TTTAK ', 0, 20000.0, 0.0, 'K0004')
# ('GI0000087', 'Kran Shower Cabang 1/2 No 43 TAMU2/AS', 0, 33000.0, 0.0, 'K0004')
# ('GI0000088', 'Kran Shower Cabang 1/2 No 41 8842 SF7 TAMU2', 0, 30000.0, 0.0, 'K0004')
# ('GI0000089', 'Kran Tembok Onda M 03908 1/2 On2 ', 0, 199500.0, 0.0, 'K0004')
# ('GI0000090', 'Kran Tembok Onda F 320 TG 1/2 On19', 0, 196250.0, 0.0, 'K0004')
# ('GI0000091', 'Kran Tembok Onda F320PJ 1/2 On18 ', 0, 206500.0, 0.0, 'K0004')
# ('GI0000092', 'Kran Tembok Onda F330LS 1/2 On10', 0, 212250.0, 0.0, 'K0004')
# ('GI0000093', 'Kran Tembok Onda F800Y 1/2 On12', 0, 122250.0, 0.0, 'K0004')
# ('GI0000094', 'Kran Tembok DUPON 698 NC 1/2 DP ', 0, 0.0, 0.0, 'K0004')
# ('GI0000095', 'Kran Tembok DUPON Y812NC 1/2 DP12', 0, 344400.0, 0.0, 'K0004')
# ('GI0000096', 'Kran Tembok DUPON B813NC 1/2 DP14', 0, 355500.0, 0.0, 'K0004')
# ('GI0000097', 'Kran Tembok DUPON 684NC 1/2 DP16 ', 0, 222200.0, 0.0, 'K0004')
# ('GI0000098', 'Kran Tembok DUPON B683NC 1/2 DP22', 0, 233300.0, 0.0, 'K0004')
# ('GI0000099', 'Kran Tembok DUPON B613NC 1/2 DP18 ', 0, 188800.0, 0.0, 'K0004')
# ('GI0000100', 'Kran Tembok WASSER TL-030 1/2 WS26 ', 0, 205000.0, 0.0, 'K0004')
# ('GI0000101', 'Kran Tembok WASSER TL-030B 1/2 WS22 ', 0, 214000.0, 0.0, 'K0004')
# ('GI0000102', 'Kran Tembok WASSER TL2-030 1/2 - ', 0, 216000.0, 0.0, 'K0004')
# ('GI0000103', 'Kran Tembok WASSER TC2-030 1/2 -', 0, 223000.0, 0.0, 'K0004')
# ('GI0000104', 'Kran Tembok WASSER TL3-030 1/2 -', 0, 210000.0, 0.0, 'K0004')
# ('GI0000105', 'Kran Tembok WASSER TB-030 1/2 -', 0, 190000.0, 0.0, 'K0004')
# ('GI0000106', 'Kran Tembok WASSER TL2-0112 1/2 -', 0, 201000.0, 0.0, 'K0004')
# ('GI0000107', 'Kran Tembok WASSER TB-010 1/2 WS15', 0, 153000.0, 0.0, 'K0004')
# ('GI0000108', 'Kran Tembok WASSER TL3-010 1/2 -', 0, 168000.0, 0.0, 'K0004')
# ('GI0000109', 'Kran Tembok WASSER TC2-010 1/2 -', 0, 199000.0, 0.0, 'K0004')
# ('GI0000110', 'Kran Tembok WASSER TL2-010 1/2 -', 0, 171000.0, 0.0, 'K0004')
# ('GI0000111', 'Kran Tembok WASSER TC-010b 1/2 WS24 ', 0, 189000.0, 0.0, 'K0004')
# ('GI0000112', 'Kran Tembok WASSER TL-010 1/2 WS27', 0, 163000.0, 0.0, 'K0004')
# ('GI0000113', 'Kran Tembok TOTO TX130L 1/2 - ', 0, 289000.0, 0.0, 'K0004')
# ('GI0000114', ' Kran Tembok TOTO T23B13V7NB 1/2 -', 0, 220000.0, 0.0, 'K0004')
# ('GI0000115', 'Kran Tembok TOTO T23B13B 1/2 -', 0, 214000.0, 0.0, 'K0004')
# ('GI0000116', 'Kran Bath Up MIXER Onda B80001 1/2 On28-29', 0, 1705250.0, 0.0, 'K0012')
# ('GI0000117', 'Kran Bath Up MIXER Onda B40001 1/2 On30-31', 0, 448500.0, 0.0, 'K0012')
# ('GI0000118', 'Kran Bath Up MIXER DUPON S6914NC 1/2 DP9', 0, 866600.0, 0.0, 'K0012')
# ('GI0000119', 'Kran Bath Up MIXER DUPON S5938NC 1/2 DP4', 0, 632500.0, 0.0, 'K0012')
# ('GI0000120', 'Kran Bath Up MIXER WASSER MBTS1110 1/2 WS10', 0, 646000.0, 0.0, 'K0012')
# ('GI0000121', 'Kran Bath Up MIXER WASSER MBTS1910 1/2 -', 0, 778000.0, 0.0, 'K0012')
# ('GI0000122', 'Kran Bath Up MIXER WASSER MBTS1510 1/2 - - ', 0, 745500.0, 0.0, 'K0012')
# ('GI0000123', 'Kran Bath Up MIXER WASSER MSWS1020 1/2 - -', 0, 478000.0, 0.0, 'K0012')
# ('GI0000124', 'Kran Bath Up MIXER WASSER MBT-S010 1/2 - -', 0, 646000.0, 0.0, 'K0012')
# ('GI0000125', 'Kran Bath Up MIXER WASSER MBT-S1010 1/2 WS12 ', 0, 562000.0, 0.0, 'K0012')
# ('GI0000126', 'Kran Bath Up MIXER WASSER MBT-S0101 1/2 - -', 0, 688000.0, 0.0, 'K0012')
# ('GI0000127', 'Kran Bath Up MIXER WASSER MBT-S2010 1/2 - - ', 0, 610000.0, 0.0, 'K0012')
# ('GI0000128', 'Kran Wastafel Mixing Onda B39014 1/2 On34 ', 0, 542500.0, 0.0, 'K0012')
# ('GI0000129', 'Kran Wastafel Mixing Onda B04014 1/2 On40 ', 0, 376805.0, 0.0, 'K0012')
# ('GI0000130', 'Kran Wastafel Onda M03901 1/2 On43', 0, 215000.0, 0.0, 'K0012')
# ('GI0000131', 'Kran Wastafel Onda F340PJ 1/2 On44', 0, 259750.0, 0.0, 'K0012')
# ('GI0000132', 'Kran Wastafel Onda F340BU 1/2 On45', 0, 203500.0, 0.0, 'K0012')
# ('GI0000133', 'Kran Wastafel Onda F340TG 1/2 On47', 0, 246500.0, 0.0, 'K0012')
# ('GI0000134', 'Kran Wastafel Onda F3501 1/2 On48', 0, 531500.0, 0.0, 'K0012')
# ('GI0000135', 'Kran Wastafel Onda F360LS 1/2 On49 ', 0, 807500.0, 0.0, 'K0012')
# ('GI0000136', 'Kran Wastafel DUPON SF4915NC 1/2 DP24', 0, 777700.0, 0.0, 'K0012')
# ('GI0000137', 'Kran Wastafel DUPON GSF8802DC 1/2 DP29', 0, 1555000.0, 0.0, 'K0012')
# ('GI0000138', 'Kran Wastafel DUPON B443NC 1/2 DP30', 0, 266600.0, 0.0, 'K0012')
# ('GI0000139', 'Kran Wastafel DUPON A455NC 1/2 DP31 ', 0, 422200.0, 0.0, 'K0012')
# ('GI0000140', 'Kran Wastafel DUPON Y4702NC 1/2 DP32 ', 0, 200000.0, 0.0, 'K0012')
# ('GI0000141', 'Kran Wastafel WASSER TL3-060S 1/2 - -  ', 0, 235000.0, 0.0, 'K0012')
# ('GI0000142', 'Kran Wastafel WASSER TC-060B 1/2 WS4 ', 0, 256000.0, 0.0, 'K0012')
# ('GI0000143', 'Kran Wastafel WASSER TL-060 1/2 WS2', 0, 229000.0, 0.0, 'K0012')
# ('GI0000144', 'Kran Wastafel WASSER TL2-026T 1/2  - - ', 0, 575000.0, 0.0, 'K0012')
# ('GI0000145', 'Kran Wastafel WASSER TC2-061M 1/2 - - ', 0, 544000.0, 0.0, 'K0012')
# ('GI0000146', 'Kran Wastafel WASSER TL2-061M 1/2 - - ', 0, 476000.0, 0.0, 'K0012')
# ('GI0000147', 'Kran Wastafel WASSER TBA-S2035 1/2 - - ', 0, 480000.0, 0.0, 'K0012')
# ('GI0000148', 'Kran Wastafel WASSER TBA-S031 1/2 - - ', 0, 511000.0, 0.0, 'K0012')
# ('GI0000149', 'Kran Shower WASSER TL2-070 1/2 - - ', 0, 133000.0, 0.0, 'K0012')
# ('GI0000150', 'Kran Shower WASSER SK-002 1/2 - - ', 0, 58000.0, 0.0, 'K0012')
# ('GI0000151', 'Kran Shower WASSER TL-070 1/2 WS14 ', 0, 116000.0, 0.0, 'K0012')
# ('GI0000152', 'Kran Shower WASSER TL-080 1/2 WS13 ', 0, 111000.0, 0.0, 'K0012')
# ('GI0000153', 'Kran Shower WASSER TC-070B 1/2 WS16', 0, 134000.0, 0.0, 'K0012')
# ('GI0000154', 'Kran Shower Cabang WASSER TC-090B 1/2 WS19', 0, 205000.0, 0.0, 'K0012')
# ('GI0000155', 'Kran Shower Cabang WASSER SK004 1/2 - -', 0, 95000.0, 0.0, 'K0012')
# ('GI0000156', 'Kran Shower Cabang WASSER SK003 1/2 - -', 0, 99000.0, 0.0, 'K0012')
# ('GI0000157', 'Kran Shower Tanam WASSER TL2-080 1/2 - - ', 0, 289000.0, 0.0, 'K0012')
# ('GI0000158', 'Kran Wastafel Campur DUPON 1/2 DP46 ', 0, 45000.0, 0.0, 'K0012')
# ('GI0000159', 'Kran Wastafel Campur GZR A58 TEU3 1/2 ', 0, 30000.0, 0.0, 'K0012')
# ('GI0000160', 'Kran Wastafel Campur IVERO A57 1U4 1/2 ', 0, 77500.0, 0.0, 'K0012')
# ('GI0000161', 'Kran Wastafel Campur ZH2935 A58A DMU3 1/2 - -', 0, 135000.0, 0.0, 'K0012')
# ('GI0000162', 'Kran Wastafel Campur KWT 116 A56 AU4 1/2 - - ', 0, 110000.0, 0.0, 'K0012')
# ('GI0000163', 'Kran Wastafel Campur HZX A55 MMU3 1/2 ', 0, 75000.0, 0.0, 'K0012')
# ('GI0000164', 'Kran Wastafel Campur CHETY A54 KOMU2 1/2 - -', 0, 170000.0, 0.0, 'K0012')
# ('GI0000165', 'Kran Wastafel Campur GZR A41 TEU4 1/2 - - ', 0, 165000.0, 0.0, 'K0012')
# ('GI0000166', 'Kran Wastafel Campur AUGUSTO 42 KU4 1/2 - - ', 0, 130000.0, 0.0, 'K0012')
# ('GI0000167', 'Kran Wastafel Campur MAVE A48 - 1/2 - ', 0, 165000.0, 0.0, 'K0012')
# ('GI0000168', 'Kran Shower Onda JF02HA 1/2 On20 - ', 0, 106250.0, 0.0, 'K0012')
# ('GI0000169', 'Kran Shower Cabang Onda SV11TG 1/2 On21 - ', 0, 96250.0, 0.0, 'K0012')
# ('GI0000170', 'Kran Shower Cabang Onda SV11LS On07 1/2 -', 0, 140000.0, 0.0, 'K0012')
# ('GI0000171', 'Kran Shower DUPON 471-NC 1/2 - - ', 0, 122200.0, 0.0, 'K0012')
# ('GI0000172', 'Kran Double Onda E08LG 1/2 On03 -', 0, 262500.0, 0.0, 'K0012')
# ('GI0000173', 'Kran Double DUPON 624NC 1/2 DP17 -', 0, 305500.0, 0.0, 'K0012')
# ('GI0000174', 'Kran Double DUPON Y6202NC 1/2 DP19 ', 0, 283300.0, 0.0, 'K0012')
# ('GI0000175', 'Kran Double DUPON B623NC 1/2 DP21 - ', 0, 327700.0, 0.0, 'K0012')
# ('GI0000176', 'Kran Double WASSER TB-020 1/2 - -', 0, 278000.0, 0.0, 'K0012')
# ('GI0000177', 'Kran Double WASSER TL3-020 1/2 - -', 0, 295000.0, 0.0, 'K0012')
# ('GI0000178', 'Kran Double WASSER TL2-020 1/2 - -', 0, 357000.0, 0.0, 'K0012')
# ('GI0000179', 'Kran Double WASSER TC020B 1/2 WS21 -', 0, 324000.0, 0.0, 'K0012')
# ('GI0000180', 'Kran Double WASSER TL020 1/2 WS28 -', 0, 289000.0, 0.0, 'K0012')
# ('GI0000181', 'Kran Double TOTO TX423ST1 1/2 - -', 0, 469000.0, 0.0, 'K0012')
# ('GI0000182', 'Kran Wastafel FLIESSEN 1/2 - Basin Mixer 0101-101', 0, 688653.0, 0.0, 'K0012')
# ('GI0000183', 'Kran Wastafel FLIESSEN 1/2 - Cold Water Tap 0101-03c', 0, 472175.0, 0.0, 'K0012')
# ('GI0000184', 'Kran Wastafel FLIESSEN 1/2 - Cold Water Tap 0101-05c', 0, 499950.0, 0.0, 'K0012')
# ('GI0000185', 'Kran Wastafel FLIESSEN 1/2 - Cold Water Tap 0101-04c', 0, 444400.0, 0.0, 'K0012')
# ('GI0000186', 'Kran Wastafel FLIESSEN 1/2 - Basin Mixer 0101-04', 0, 664900.0, 0.0, 'K0012')
# ('GI0000187', 'Kran Wastafel FLIESSEN 1/2 - Cold Water Kitchen Tap 0106-02c', 0, 555500.0, 0.0, 'K0012')
# ('GI0000188', 'Kran Wastafel FLIESSEN 1/2 - Kitchen Faucet 0111-00', 0, 444400.0, 0.0, 'K0012')
# ('GI0000189', 'Kran Wastafel FLIESSEN 1/2 - Kitchen Faucet 0104-00 S.S spout ', 0, 499950.0, 0.0, 'K0012')
# ('GI0000190', 'Kran Wastafel FLIESSEN 1/2 - Kitchen Faucet 0106-02', 0, 708373.0, 0.0, 'K0012')
# ('GI0000191', 'Kran Bath Up FLIESSEN 1/2 - Bath Faucet 0109-05', 0, 846000.0, 0.0, 'K0012')
# ('GI0000192', 'Kran Bath Up Shower Tanam FLIESSEN 1/2 - Concealed Bath 0110-102', 0, 555500.0, 0.0, 'K0012')
# ('GI0000193', 'Kran Bath Up +Mixer FLIESSEN 1/2 - BT05 TKMU3/AW ', 0, 320000.0, 0.0, 'K0012')
# ('GI0000194', 'Kran Bath Up Shower  FLIESSEN 1/2 BT01 TDMU3/PJ  ', 0, 295000.0, 0.0, 'K0012')
# ('GI0000195', 'Kran Bath up Padova FLIESSEN Bath Faucet 0109-00 BT04 TDMU3', 0, 275000.0, 0.0, 'K0012')
# ('GI0000196', 'Hand Shower WASSER 1/2 - SH5563  ', 0, 225000.0, 0.0, 'K0013')
# ('GI0000197', 'Hand Shower WASSER 1/2 WS34A SH5533', 0, 225000.0, 0.0, 'K0013')
# ('GI0000198', 'Hand Shower WASSER 1/2 - SH5565 ', 0, 268000.0, 0.0, 'K0013')
# ('GI0000199', 'Hand Shower WASSER 1/2 WS33 CH5535 ', 0, 288000.0, 0.0, 'K0013')
# ('GI0000200', 'Hand Shower WASSER 1/2 - SH5567 ', 0, 318000.0, 0.0, 'K0013')
# ('GI0000201', 'Hand Shower WASSER 1/2 WS34 SH5536', 0, 305000.0, 0.0, 'K0013')
# ('GI0000202', 'Hand Shower WASSER 1/2 - SH5568', 0, 348000.0, 0.0, 'K0013')
# ('GI0000203', 'JET SHOWER WASSER 1/2 - WS89TS PUTIH ', 0, 95000.0, 0.0, 'K0013')
# ('GI0000204', 'JET SHOWER WASSER 1/2 - WS99JS', 0, 143000.0, 0.0, 'K0013')
# ('GI0000205', 'JET SHOWER WASSER 1/2 - WS99JS Warna IVORY', 0, 143000.0, 0.0, 'K0013')
# ('GI0000206', 'JET SHOWER WASSER 1/2 - WS89TS Warna Ivory ', 0, 95000.0, 0.0, 'K0013')
# ('GI0000207', 'JET SHOWER WASSER 1/2 - 99JS Warna Chrome ', 0, 189000.0, 0.0, 'K0013')
# ('GI0000208', 'JET SHOWER WASSER 1/2 - WS88TS Warna Ivory', 0, 89500.0, 0.0, 'K0013')
# ('GI0000209', 'JET SHOWER WASSER 1/2 - WS100TS Warna Ivory ', 0, 55000.0, 0.0, 'K0013')
# ('GI0000210', 'SIFON WASSER POP UP - BTW002306', 0, 399000.0, 0.0, 'K0010')
# ('GI0000211', 'FLOOR DRAIN WASSER - - HSA-6042 ', 0, 254500.0, 0.0, 'K0010')
# ('GI0000212', 'FLOOR DRAIN WASSER - - HSA-6442', 0, 282000.0, 0.0, 'K0010')
# ('GI0000213', 'JET SHOWER CHROME ONDA TS02 C 1/2 On15    ', 0, 115500.0, 0.0, 'K0013')
# ('GI0000214', 'JET SHOWER PUTIH ONDA 1/2 On14 TS02P ', 0, 115500.0, 0.0, 'K0013')
# ('GI0000215', 'Hand Shower DUPON 6510 NC 1/2 DP1 ', 0, 166600.0, 0.0, 'K0013')
# ('GI0000217', 'Hand Shower MASSAGE DUPON 6513-P43 1/2 DP35', 0, 161100.0, 0.0, 'K0013')
# ('GI0000218', 'JET SHOWER DUPON 1/2 DP40 P506-NCP5 ', 0, 83300.0, 0.0, 'K0013')
# ('GI0000219', 'JET SHOWER DUPON 1/2 DP38 P506-NCP1', 0, 83300.0, 0.0, 'K0013')
# ('GI0000220', 'JET SHOWER DUPON 1/2 DP6 CO5006', 0, 138800.0, 0.0, 'K0013')
# ('GI0000221', 'JET SHOWER DUPON 1/2 DP10 CO5006-NCP1', 0, 94400.0, 0.0, 'K0013')
# ('GI0000222', 'Hand Shower DUPON 1/2 DP36 6513-P13', 0, 161000.0, 0.0, 'K0013')
# ('GI0000223', 'Hand Shower DUPON 1/2 DP5 7520-P1', 0, 111100.0, 0.0, 'K0013')
# ('GI0000224', 'Hand Shower DUPON 1/2 DP34 6510-P1', 0, 100000.0, 0.0, 'K0013')
# ('GI0000225', 'WALL Shower Tembok DUPON 1/2 DP5 6013-NC3 ', 0, 188800.0, 0.0, 'K0013')
# ('GI0000226', 'Hand Shower MERCY 1/2 No 45 IMU3/AW', 0, 77500.0, 0.0, 'K0013')
# ('GI0000227', 'Hand Shower SPINKLER CLASIC 1/2 No 33 MMU3/MAX ', 0, 85000.0, 0.0, 'K0013')
# ('GI0000228', 'Hand Shower Sobar 1/2 No 24 A EMU3/SH ', 0, 47500.0, 0.0, 'K0013')
# ('GI0000229', 'Hand Shower Rain Shower Sensor 1/2 No 6 DDMU2/MA', 0, 115000.0, 0.0, 'K0013')
# ('GI0000230', 'Hand Shower DIVA 3333 1/2 No 42 AMU3/MA', 0, 97500.0, 0.0, 'K0013')
# ('GI0000231', 'Hand Shower BALLITTO 1/2 No 20 IDMU2/JH', 0, 77500.0, 0.0, 'K0013')
# ('GI0000232', 'Hand Shower BALLITTO 1/2 No 19 IDMU2/JH', 0, 77500.0, 0.0, 'K0013')
# ('GI0000233', 'Hand Shower TASSOTI 3089 1/2 No 4 DTU3/RDI', 0, 110000.0, 0.0, 'K0013')
# ('GI0000234', 'Hand Shower Carlo Fiotini 1/2 No 39 MMU3 ', 0, 82500.0, 0.0, 'K0013')
# ('GI0000235', 'Hand Shower TASSOTI 3086-2 1/2 No 2 DAU3/RDI', 0, 115000.0, 0.0, 'K0013')
# ('GI0000236', 'Hand Shower - - No 18 EIMU2 ', 0, 50000.0, 0.0, 'K0013')
# ('GI0000237', 'Hand Shower - 1/2 No 4 KU4/MA ', 0, 145000.0, 0.0, 'K0013')
# ('GI0000238', 'Hand Shower AGUSTO - No 43 ARMU2 ', 0, 95000.0, 0.0, 'K0013')
# ('GI0000239', 'Hand Shower GUPPY - No 5 MMU3SH ', 0, 75000.0, 0.0, 'K0013')
# ('GI0000240', 'Hand Shower WEIMENG  1/2 No 21 REMU2/AW', 0, 55000.0, 0.0, 'K0013')
# ('GI0000241', 'Hand Shower Carlofiotini (CD-045) 1/2 No 36 Av4/SS4 ', 0, 87500.0, 0.0, 'K0013')
# ('GI0000242', 'Hand Shower HES No 17 KU/4JH', 0, 135000.0, 0.0, 'K0013')
# ('GI0000243', 'Hand Shower Carlo Fiotini - No 24 - ', 0, 70000.0, 0.0, 'K0013')
# ('GI0000244', 'Hand Shower AGUSTO 1/2 No 43 ARMU2 ', 0, 95000.0, 0.0, 'K0013')
# ('GI0000245', 'Hand Shower Tiang DDMU3/PJ ', 2, 1150000.0, 0.0, 'K0013')
# ('GI0000246', 'JET SHOWER TOTO THX20 MCRB CHROME ', 0, 317000.0, 0.0, 'K0013')
# ('GI0000247', 'JET SHOWER TOTO THX20 NBW White ', 0, 274000.0, 0.0, 'K0013')
# ('GI0000248', 'JET SHOWER VONE HS50 CHROME RDMU2', 0, 67500.0, 0.0, 'K0013')
# ('GI0000249', 'JET SHOWER TASSOTI MRMU2 CHROME', 0, 85000.0, 0.0, 'K0013')
# ('GI0000250', 'JET SHOWER VONE HS50 MAROON  REMU2', 0, 57500.0, 0.0, 'K0013')
# ('GI0000251', 'Wall Shower Tembok WASSER 1/2 WS37 SHS588', 0, 210000.0, 0.0, 'K0010')
# ('GI0000252', 'Wall Shower Tembok SHS786 ', 0, 272000.0, 0.0, 'K0013')
# ('GI0000253', 'Wall Shower Tembok LED CB-H518 1/2 A2 OMU3/SH', 0, 145000.0, 0.0, 'K0013')
# ('GI0000254', 'WALL Shower Tembok GZR ORANGE HIJAU 1/2 A4 EMU3/SH', 0, 40000.0, 0.0, 'K0013')
# ('GI0000255', 'Wall Shower Tembok - 1/2 A1 TTMU3/MA  ', 0, 155000.0, 0.0, 'K0013')
# ('GI0000256', 'Wall Shower Tembok - 20x20 A6 TEMU3/AW ', 0, 195000.0, 0.0, 'K0013')
# ('GI0000257', 'Wall Shower TembokGRITANIA 6119 Kuningan 1/2 TUS/MA A38-1', 0, 185000.0, 0.0, 'K0013')
# ('GI0000258', 'Wall Shower Tembok T102 1/2 A55 RAMU/PJ', 0, 73000.0, 0.0, 'K0013')
# ('GI0000259', 'KUKU MACAN 20 CM MOLDURA KM1 ULIR BEIGE ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000260', 'KUKU MACAN 20 CM MOLDURA KM2 ULIR DARK GREEN ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000261', 'KUKU MACAN 20 CM MOLDURA KM3 ULIR PASTEL PINK ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000262', 'KUKU MACAN 20 CM MOLDURA KM4 SOFT BROWN / COCO BROWN ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000263', 'KUKU MACAN 20 CM MOLDURA KM5 ULIR SOFT BLUE ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000264', 'KUKU MACAN 20 CM MOLDURA KM6 ULIR WHITE ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000265', 'KUKU MACAN 20 CM MOLDURA KM7 ULIR DARK BLUE ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000266', 'KUKU MACAN 20 CM MOLDURA KM8 ULIR PASTEL MARON ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000267', 'KUKU MACAN 20 CM MOLDURA KM9 ULIR ORANGE ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000268', 'KUKU MACAN 20 CM MOLDURA KM10 GREEN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000269', 'KUKU MACAN 20 CM MOLDURA KM11 ULIR DARK BROWN ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000270', 'KUKU MACAN 20 CM MOLDURA KM12 ULIR SKY BLUE', 0, 1200.0, 0.0, 'K0017')
# ('GI0000271', 'KUKU MACAN 20 CM MOLDURA KM13 ULIR GREY ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000272', 'KUKU MACAN 20 CM MOLDURA KM14 ICE BLUE', 0, 1200.0, 0.0, 'K0017')
# ('GI0000273', 'KUKU MACAN 20 CM MOLDURA KM15 ULIR MARON  ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000274', 'KUKU MACAN 20 CM MOLDURA KM16 ULIR HITAM', 0, 1200.0, 0.0, 'K0017')
# ('GI0000275', 'KUKU MACAN 20 CM MOLDURA KM17 LEAF GREEN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000276', 'KUKU MACAN 20 CM MOLDURA KM18 MILK BROWN ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000277', 'KUKU MACAN 20 CM MOLDURA KM19 BROWN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000278', 'KUKU MACAN 20 CM MOLDURA KM20 ULIR OLIEF GREEN ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000279', 'KUKU MACAN 20 CM MOLDURA KM21 ULIR YELLOW ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000280', 'KUKU MACAN 20 CM MOLDURA KM22 ULIR IVORY ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000281', 'KUKU MACAN 20 CM MOLDURA KM23 POLOS BROWN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000282', 'KUKU MACAN 20 CM MOLDURA KM24 POLOS BEIGE', 0, 1200.0, 0.0, 'K0017')
# ('GI0000283', 'KUKU MACAN 20 CM MOLDURA KM25 POLOS IVORY ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000284', 'KUKU MACAN 20 CM MOLDURA KM26 POLOS PUTIH', 0, 1200.0, 0.0, 'K0017')
# ('GI0000285', 'KUKU MACAN 20 CM MOLDURA KM27 POLOS GREY', 0, 1200.0, 0.0, 'K0017')
# ('GI0000286', 'KUKU MACAN 20 CM MOLDURA KM28 POLOS BLACK', 0, 1200.0, 0.0, 'K0017')
# ('GI0000287', 'KUKU MACAN 20 CM MOLDURA KM29 POLOS PINK', 0, 1200.0, 0.0, 'K0017')
# ('GI0000288', 'KUKU MACAN 20 CM MOLDURA KM30 POLOS DARK BLUE', 0, 1200.0, 0.0, 'K0017')
# ('GI0000289', 'KUKU MACAN 20 CM MOLDURA KM31 POLOS MAROON', 0, 1200.0, 0.0, 'K0017')
# ('GI0000290', 'KUKU MACAN 20 CM MOLDURA KM32 POLOS DARK BROWN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000291', 'KUKU MACAN 20 CM MOLDURA KM33 POLOS SOFT BROWN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000292', 'KUKU MACAN 20 CM MOLDURA KM34 POLOS DARK GREEN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000293', 'KUKU MACAN 20 CM MOLDURA KM35 POLOS GREEN', 0, 1200.0, 0.0, 'K0017')
# ('GI0000294', 'KUKU MACAN 20 CM MOLDURA KM36 POLOS SOFT GREEN ', 0, 1200.0, 0.0, 'K0017')
# ('GI0000295', 'KUKU MACAN 20 CM MOLDURA KM37 POLOS SOFT BLUE', 0, 1200.0, 0.0, 'K0017')
# ('GI0000296', 'RAK HANDUK - A827 B43 TAU4/JH ', 0, 245000.0, 0.0, 'K0011')
# ('GI0000297', 'RAK HANDUK - RH-1-60-1000 B42 IEMU2/JH', 0, 77500.0, 0.0, 'K0011')
# ('GI0000298', 'HANDLE HAND WITH SOAP DUPON - H544NC', 0, 538800.0, 0.0, 'K0011')
# ('GI0000299', 'CAPSTOK FENGMIE B25 MMU3', 0, 97500.0, 0.0, 'K0011')
# ('GI0000300', 'RAK KAWAT DOUBLE OVAL GRAVINO 0021 ALUMUNIUM B52 TRMU3/JH', 0, 235000.0, 0.0, 'K0011')
# ('GI0000301', 'RAK KAWAT SEGI 6 B64 MMU3/PJ', 0, 95000.0, 0.0, 'K0011')
# ('GI0000302', 'TOWEL BAR 6900 B6 EDTEMU', 0, 345500.0, 0.0, 'K0011')
# ('GI0000303', 'TEMPAT TISU + SABUN FRISONE KUNING B64BMU4/SH ', 0, 85000.0, 0.0, 'K0011')
# ('GI0000304', 'TEMPAT TISU + SABUN FRISONE BIRU B64B MU4/SH ', 0, 85000.0, 0.0, 'K0011')
# ('GI0000305', 'AUTOMATIC HAND DRYER DUPON 1000 WATT - - ', 0, 1000000.0, 0.0, 'K0011')
# ('GI0000306', 'TEMPAT TISU + SABUN FRISONE PUTIH / BENING B64B MU4/SH ', 0, 85000.0, 0.0, 'K0011')
# ('GI0000307', 'TEMPAT TISSUE ERNESTO - B23 DMU3/JH  ', 0, 150000.0, 0.0, 'K0011')
# ('GI0000308', 'DOUBLE TOILET PAPER DUPON - - ', 0, 566600.0, 0.0, 'K0011')
# ('GI0000309', 'TEMPAT SIKAT GIGI + GELAS DUPON ', 0, 142500.0, 0.0, 'K0011')
# ('GI0000310', 'RAK STAINLES ERNESTO 3025 0038 ER4321 40 CM B11 IMU3/JH', 0, 77500.0, 0.0, 'K0011')
# ('GI0000311', 'RAK STAINLES ERNESTO 3025 0039 ER4321 50 CM B14B MU4/JH', 0, 82500.0, 0.0, 'K0011')
# ('GI0000312', 'RAK STAINLES ERNESTO 3025 0047 ER4321 60 CM B11A MMU3/JH', 0, 87500.0, 0.0, 'K0011')
# ('GI0000313', 'DOUBLE TOILET PAPER DUPON - - ', 0, 500000.0, 0.0, 'K0011')
# ('GI0000314', 'SKIN DRYER DUPON 800 WATT - - ', 0, 1388000.0, 0.0, 'K0011')
# ('GI0000315', 'HAIR DRYER DUPON - - ', 0, 666600.0, 0.0, 'K0011')
# ('GI0000316', 'RAK SABUN SUDUT FIORENTINA 2 SUSUN - B14 TRMU3/JH', 0, 215000.0, 0.0, 'K0011')
# ('GI0000317', 'KAPSTOK + KERANJANG FIO 901 B9 AU4/MA ', 0, 105000.0, 0.0, 'K0011')
# ('GI0000318', 'PLANKSET KACA WIKEA 5013 50 CM B17 DMU3/MA ', 0, 130000.0, 0.0, 'K0011')
# ('GI0000319', 'RAK HANDUK + CAPSTOK 8810 70 X 23 X 16 B48 TOMU3/MA ', 0, 295000.0, 0.0, 'K0011')
# ('GI0000320', 'PLANKSET KACA AMU3 B53 ', 0, 125000.0, 0.0, 'K0011')
# ('GI0000321', 'MIROR BOX MASPION PINK  MC5 40 X 47 X 10 - TUKU3', 0, 125000.0, 0.0, 'K0011')
# ('GI0000322', 'RAK HANDUK 4500 RACK TOWEL 60 CM X 10 CM B34 RMU3/SSA', 0, 60000.0, 0.0, 'K0011')
# ('GI0000323', 'TEMPAT T SABUN CAIR WIKA C37 RAMU2/PJ ', 0, 57500.0, 0.0, 'K0011')
# ('GI0000324', 'TEMPAT T SABUN CAIR TS CAIR FIORENTINO - C37A IIU3/PJ', 0, 75000.0, 0.0, 'K0011')
# ('GI0000325', 'TEMPAT T SABUN TS CAIR DG 1660411 DE LA BERTO - C32 DMU3  ', 0, 150000.0, 0.0, 'K0011')
# ('GI0000326', 'KAPSTOK BAJU A CAPSTOK 610 - C24 EMU3/MA', 0, 52500.0, 0.0, 'K0011')
# ('GI0000327', 'T TISSUE + ASBAK FIORENTINO KE 18 - C9 IDMU2/JH ', 0, 85000.0, 0.0, 'K0011')
# ('GI0000328', 'CAPSTOK NADA - C19 IU4/MA', 0, 65000.0, 0.0, 'K0011')
# ('GI0000329', 'RAK HANDUK DOBEL ALUMUNIUM GRAVINO 0027 70 CM B27 TRM3/JH', 0, 237500.0, 0.0, 'K0011')
# ('GI0000330', 'RAK HANDUK + KAPSTOK TODINI 6627 60 CM X 24 CM B24 TDMU3/JH', 0, 315000.0, 0.0, 'K0011')
# ('GI0000331', 'RAK HANDUK 6653TOWEL RAK 60 CM B60A TMU4/JH', 0, 245000.0, 0.0, 'K0011')
# ('GI0000332', 'RAK HANDUK + KAPSTOK GRAVINO A700 70 CM B15 TIUA/JH', 0, 245000.0, 0.0, 'K0011')
# ('GI0000333', 'RAK HANDUK + KAPSTOK TODINI 6643 56 X 25 X 10 CM B7A ETU4/JH', 0, 350000.0, 0.0, 'K0011')
# ('GI0000334', 'RAK HANDUK 2 SUSUN MARCERA 60 CM B5 OMU3/PJ', 0, 145000.0, 0.0, 'K0011')
# ('GI0000335', 'RAK HANDUK LIVANO 60 CM B4 TMMU3/SH', 0, 285000.0, 0.0, 'K0011')
# ('GI0000336', 'RAK STEINLESS G07-Z TODINI 49 X 12,5 CM NO 4 DMU3/JH', 0, 125000.0, 0.0, 'K0011')
# ('GI0000337', 'RAK HANDUK STLS FIORENTINO - B40 TDMU2/JH', 0, 265000.0, 0.0, 'K0011')
# ('GI0000338', 'RAK STEINLESS 2 SUSUN TODINI G07-2 40 X 40 X 13 CM NO 6 TIU4/JH', 0, 230000.0, 0.0, 'K0011')
# ('GI0000339', 'SINGLE LAYER GLASS 50 CM DUPON L05', 0, 205500.0, 0.0, 'K0011')
# ('GI0000340', 'RAK HANDUK ALUMUNIUM B8 ', 0, 275000.0, 0.0, 'K0011')
# ('GI0000341', 'RAK HANDUK ALUMUNIUM AO26  B10  OMU3/SSA', 0, 110000.0, 0.0, 'K0011')
# ('GI0000342', 'RAK HANDUK HESA 60 CM B12 TIMU3/JH', 0, 275000.0, 0.0, 'K0011')
# ('GI0000343', 'HANDEL BATH UP FIORENTINO 35 CM B48 MMU3/PJ', 0, 82500.0, 0.0, 'K0011')
# ('GI0000344', 'GLASS HOLDER FR-7330B B35 TUMU3/SSA ', 0, 175000.0, 0.0, 'K0011')
# ('GI0000345', 'RAK KAWAT SABUN FLO - B41 TAU3/JH ', 0, 30000.0, 0.0, 'K0011')
# ('GI0000346', 'RAK KAWAT SABUN FLO - B41A TAU3/JH ', 0, 30000.0, 0.0, 'K0011')
# ('GI0000347', 'RAK HANDUK FIORENTINO 60 CM B45 TIMU3/PJ', 0, 250000.0, 0.0, 'K0011')
# ('GI0000348', 'RAK KAWAT ALUMUNIUM DUPON L-145 SHELF 10 X 28 CM B18 ATD/U2', 0, 122200.0, 0.0, 'K0011')
# ('GI0000349', 'RAK KAWAT SUDUT ALUMUNIUM DUPON L-135 18X18 CM DP3 - ', 0, 105500.0, 0.0, 'K0011')
# ('GI0000350', 'TEMPAT TISSUE + SABUN FRISONE PINK B64B MU5/SH ', 0, 85000.0, 0.0, 'K0011')
# ('GI0000351', 'AEROSOL DISPENSER PENGHARUM RUANGAN - B31 TU5', 0, 150000.0, 0.0, 'K0011')
# ('GI0000352', 'RAK STAINLESS 2 SUSUN TODINI G11 30X23X40 CM NO 1 EU5/JH', 0, 320000.0, 0.0, 'K0011')
# ('GI0000353', 'TEMPAT SABUN CAIR FIORENTINO B50 AMU3/MA', 0, 125000.0, 0.0, 'K0011')
# ('GI0000354', 'KAPSTOK BAJU 5 KAIT KAPSTOK 659 47 CM C37 10MU2/PJ', 0, 85000.0, 0.0, 'K0011')
# ('GI0000355', 'KAPSTOK KUPU BELLUCI C37C DMU2/PJ', 0, 18500.0, 0.0, 'K0011')
# ('GI0000356', 'CAPSTOK ENGKEL NA 200 ANTIQUE (2 BIJI) - C25 OMU2/JH', 0, 20000.0, 0.0, 'K0011')
# ('GI0000357', 'CAPSTOK ENGKEL NA 200 SILVER - C23 OMU2/JH', 0, 20000.0, 0.0, 'K0011')
# ('GI0000358', 'CAPSTOK ENGKEL - - E17 EEMU2/SSA', 0, 35000.0, 0.0, 'K0011')
# ('GI0000359', 'CAPSTOK FREE C1 ', 0, 12500.0, 0.0, 'K0011')
# ('GI0000360', 'KAPSTOK ENGKEL -  -  E15 EEMU2/SSA', 0, 35000.0, 0.0, 'K0011')
# ('GI0000361', 'CAPSTOK BAJU DIVA C19A EDMU2/MA', 0, 42500.0, 0.0, 'K0011')
# ('GI0000362', 'CAPSTOK STL E60 - E20 RLU3/JH', 0, 46000.0, 0.0, 'K0011')
# ('GI0000363', 'CAPSTOK C-18 RIVERO ITALIA - B61 EOMU2/JH', 0, 57500.0, 0.0, 'K0011')
# ('GI0000364', 'KAPSTOK KLV7 SKAIT B47 AEMU2/JH', 0, 95000.0, 0.0, 'K0011')
# ('GI0000365', 'CAPSTOK FIORENTINO - E14 EMU3 ', 0, 40000.0, 0.0, 'K0011')
# ('GI0000366', 'CAPSTOK 227 - NO 48 MMU3', 0, 87500.0, 0.0, 'K0011')
# ('GI0000367', 'KAPSTOK ENGKEL DR 100 SN SILVER - C24B DU3/JH', 0, 17500.0, 0.0, 'K0011')
# ('GI0000368', 'KAPSTOK ENGKEL R 100 GP GOLD PLATED C27 DU3/JH', 0, 17500.0, 0.0, 'K0011')
# ('GI0000369', 'KAPSTOK ENGKEL R 100 SL SILVER C24A DU3/JH', 0, 17500.0, 0.0, 'K0011')
# ('GI0000370', 'MIROR BOX MASPION MARON  MC5 40 X 47 X 10 - TUKU3', 0, 125000.0, 0.0, 'K0011')
# ('GI0000371', 'MIROR BOX MASPION PUTIH MC5 40 X 47 X 10 - TUKU3', 0, 125000.0, 0.0, 'K0011')
# ('GI0000372', 'MIROR BOX MASPION IVORY MC5 40 X 47 X 10 - TUKU3', 0, 125000.0, 0.0, 'K0011')
# ('GI0000373', 'MIROR PLANGSET KACA OVAL DMU3  ', 0, 115000.0, 0.0, 'K0032')
# ('GI0000374', 'MIROR PLANGSET KACA OVAL POLOS DMU3', 0, 105000.0, 0.0, 'K0032')
# ('GI0000375', 'MIROR KACA OVAL TELUR DMU3 ', 0, 105000.0, 0.0, 'K0032')
# ('GI0000376', 'KASTOK STRAIT ICHINO STAINLESS 33 CM C7 RDMU2/MX', 0, 67500.0, 0.0, 'K0011')
# ('GI0000377', 'KAPSTOK 2 X 5 KAIT DIVA 48 CM C2 EU4/PJ', 0, 55000.0, 0.0, 'K0011')
# ('GI0000378', 'KAPSTOK 5 KAIT FIORENTINO 38 CM C27 EMU3/PJ', 0, 50000.0, 0.0, 'K0011')
# ('GI0000379', 'KAPSTOK DOUBLE CROM C6 TEMU2', 0, 20000.0, 0.0, 'K0011')
# ('GI0000380', 'KAPSTOK 6 KAIT GOLD KAPSTOK 40 CM C38A TMU3/JH', 0, 30000.0, 0.0, 'K0011')
# ('GI0000381', 'KAPSTOK DOUBLE HOOK JD-913 C36 EU4/SSA', 0, 27500.0, 0.0, 'K0011')
# ('GI0000382', 'KAPSTOK BAJU FIORENTINO 30 CM C46 TEMU2/MA', 0, 22500.0, 0.0, 'K0011')
# ('GI0000383', 'KAPSTOK 4 KAIT NIKEN 38 CM C42 TAMU2/JH', 0, 32500.0, 0.0, 'K0011')
# ('GI0000384', 'KAPSTOK C43 TTU3', 0, 18500.0, 0.0, 'K0011')
# ('GI0000385', 'CAPSTOK ECO5 FIORENTINO C1 RMU3/PJ', 0, 65000.0, 0.0, 'K0011')
# ('GI0000386', 'KAPSTOK STL-102-4 KAIT C41 REMU2/JH', 0, 65000.0, 0.0, 'K0011')
# ('GI0000387', 'PROPAN AQUA POLITUR AKASIA 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000388', 'PROPAN AQUA POLITUR MAHOGANY 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000389', 'PROPAN AQUA POLITUR SHP BROWN 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000390', 'PROPAN AQUA POLITUR BRIGHT YELLOW 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000391', 'PROPAN AQUA POLITUR DEEP BLACK 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000392', 'PROPAN AQUA POLITUR CHILI RED 1 L ', 0, 68500.0, 0.0, 'K0024')
# ('GI0000393', 'PROPAN AQUA POLITUR PINKY 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000394', 'PROPAN AQUA POLITUR GREEN LEAF 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000395', 'PROPAN AQUA POLITUR WHITE WASH 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000396', 'PROPAN AQUA POLITUR TEAK 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000397', 'PROPAN AQUA POLITUR CLEAR GLOSS 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000398', 'PROPAN AQUA POLITUR VIOLET 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000399', 'PROPAN AQUA POLITUR AQUA MARINE 1 L ', 0, 68500.0, 0.0, 'K0024')
# ('GI0000400', 'PROPAN AQUA POLITUR DARK BROWN 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000401', 'PROPAN AQUA POLITUR WALNUT 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000402', 'PROPAN AQUA POLITUR LIGHT WALNUT 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000403', 'PROPAN AQUA POLITUR MAHONY 1 L ', 0, 68500.0, 0.0, 'K0024')
# ('GI0000404', 'PROPAN AQUA POLITUR CLEAR DOF 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000405', 'PROPAN AQUA POLITUR BALI YELLOW 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000406', 'PROPAN AQUA POLITUR CHERRY 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000407', 'PROPAN AQUA POLITUR SOLAR YELLOW 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000408', 'PROPAN AQUA POLITUR BROWN KJ 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000409', 'PROPAN AQUA POLITUR CANDY BROWN 1 L', 0, 68500.0, 0.0, 'K0024')
# ('GI0000410', 'PROPAN STONE CARE PELAPIS BATU ALAM GLOSS  ', 0, 69500.0, 0.0, 'K0024')
# ('GI0000411', 'PROPAN STONE CARE CAT BATU CANDI SB BLACK ', 0, 81000.0, 0.0, 'K0024')
# ('GI0000412', 'PROPAN AQUA FINISH ETU3 ', 0, 29000.0, 0.0, 'K0024')
# ('GI0000413', 'PROPAN MULTI FOX LIGHT ALABASTER ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000414', 'PROPAN MULTI FOX TRAFFIC YELLOW ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000415', 'PROPAN MULTI FOX LIGHT BLUE ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000416', 'PROPAN MULTI FOX GERANIUM ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000417', 'PROPAN MULTI FOX PALE GREEN ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000418', 'PROPAN MULTI FOX LIGHT GREY', 0, 96000.0, 0.0, 'K0024')
# ('GI0000419', 'PROPAN MULTI FOX CLEAR GLOSS', 0, 96000.0, 0.0, 'K0024')
# ('GI0000420', 'PROPAN MULTI FOX WHITE ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000421', 'PROPAN MULTI FOX LEAF GREEN ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000422', 'PROPAN MULTI FOX BEIGE ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000423', 'PROPAN MULTI FOX GENTIAN BLUE ', 0, 96000.0, 0.0, 'K0024')
# ('GI0000424', 'PROPAN AQUA PELAPIS BATU ALAM GLOSS ', 0, 66000.0, 0.0, 'K0024')
# ('GI0000425', 'LEMKRA FS NAT 201 1KG ', 0, 19500.0, 0.0, 'K0019')
# ('GI0000426', 'LEMKRA FK 101 5 KG ', 0, 33500.0, 0.0, 'K0019')
# ('GI0000427', 'LEMKRA FK 101 30 KG ', 0, 186000.0, 0.0, 'K0019')
# ('GI0000428', 'LEMKRA FK 103 1 KG ', 0, 21000.0, 0.0, 'K0019')
# ('GI0000429', 'LEMKRA FK 103 5 KG ', 0, 87500.0, 0.0, 'K0019')
# ('GI0000430', 'LEMKRA 103 30 KG ', 0, 495000.0, 0.0, 'K0019')
# ('GI0000431', 'LEMKRA FK 111 5 KG ', 0, 42500.0, 0.0, 'K0019')
# ('GI0000432', 'LEMKRA FK 111 30 KG ', 0, 235000.0, 0.0, 'K0019')
# ('GI0000433', 'LEMKRA SKIM COET 30 KG ', 0, 160000.0, 0.0, 'K0019')
# ('GI0000434', 'LEMKRA TG 301 1 LITER ', 0, 29000.0, 0.0, 'K0019')
# ('GI0000435', 'LEMKRA DS 105 WATER PROFING ', 0, 72500.0, 0.0, 'K0019')
# ('GI0000436', 'LEMKRA TG 300 2 LITER ', 0, 55000.0, 0.0, 'K0019')
# ('GI0000437', 'LEMKRA JDI PEREKAT HEBEL ', 0, 87500.0, 0.0, 'K0019')
# ('GI0000438', 'LEMKRA JDI ACIAN 30 KG ', 0, 82500.0, 0.0, 'K0019')
# ('GI0000439', 'LEMKRA A PLUS ACIAN 40 KG ', 0, 85000.0, 0.0, 'K0019')
# ('GI0000440', 'LEMKRA POWER BON PLESTER 50 KG ', 0, 82500.0, 0.0, 'K0019')
# ('GI0000441', 'SIKA NAT WHITE 256 1KG ', 0, 12500.0, 0.0, 'K0018')
# ('GI0000442', 'Keramik 20 x 20 Asia Tile Berca Red IIMU2', 0, 55000.0, 0.0, 'K0030')
# ('GI0000443', 'Keramik 20 x 20 Asia Tile Berca Blue IIMU2', 0, 55000.0, 0.0, 'K0030')
# ('GI0000444', 'Keramik 20 x 20 Arwana Maron IEMU2', 0, 54000.0, 0.0, 'K0030')
# ('GI0000445', 'Keramik 20 x 20 Asia Tile Berca Brown IIMU2', 0, 55000.0, 0.0, 'K0030')
# ('GI0000446', 'Keramik 20 x 20 Asia Tile Berca Green IIMU2', 0, 55000.0, 0.0, 'K0030')
# ('GI0000447', 'CAT TEMBOK CATYLAC EXTERIOR PINK METROPOP 43451 5 KG', 0, 156000.0, 0.0, 'K0022')
# ('GI0000448', 'Keramik 20 x 20 Mulia Clarion Blue IEMU2', 0, 52500.0, 0.0, 'K0030')
# ('GI0000449', 'Keramik 20 x 20 Mulia Candy Beige RKMU2', 0, 50000.0, 0.0, 'K0030')
# ('GI0000450', 'Keramik 20 x 20 Arwana Maron IEMU2', 0, 54000.0, 0.0, 'K0030')
# ('GI0000451', 'CAT TEMBOK CATYLAC EXTERIOR PINK METROPOP 43451 25 KG', 0, 747000.0, 0.0, 'K0023')
# ('GI0000452', 'KERAMIK 20 X 25 MULIA COLIMA GRIGIO IIU3 ', 0, 60000.0, 0.0, 'K0025')
# ('GI0000453', 'KERAMIK 20 X 25 MULIA SINAI NOCE IIU3 ', 0, 60000.0, 0.0, 'K0025')
# ('GI0000454', 'KERAMIK 20 X 25 MULIA EVERGIO BEIGE / CHERIGA BEIGE ', 0, 0.0, 0.0, 'K0025')
# ('GI0000455', 'KERAMIK 20 X 25 PICASO QUATRO LIGHT GREEN IDU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000456', 'KERAMIK 20 X 25 PICASO TRIFOGLIO LIGHT GREEN IDMU2', 0, 57500.0, 0.0, 'K0025')
# ('GI0000457', 'KERAMIK 20 X 25 PICASO TRIFOGLIO BEIGE IDMU2 ', 0, 57500.0, 0.0, 'K0025')
# ('GI0000458', 'KERAMIK 20 X 25 PICASO TRIFOGLIO LIGHT GREY IDMU2', 0, 57500.0, 0.0, 'K0025')
# ('GI0000459', 'KERAMIK 20 X 25 PICASO TRIFOGLIO LIGHTPINK IDMU2', 0, 57500.0, 0.0, 'K0025')
# ('GI0000460', 'KERAMIK 20 X 25 ARWANA UNO BLUE ', 0, 0.0, 0.0, 'K0025')
# ('GI0000461', 'KERAMIK 20 X 25 ARWANA UNO GREEN ', 0, 0.0, 0.0, 'K0025')
# ('GI0000462', 'KERAMIK 20 X 25 IKAD BATU BROWN / SIERA PEACH ', 0, 0.0, 0.0, 'K0025')
# ('GI0000463', 'KERAMIK 30 X 60 IKAD CREAM 6227 OU4 ', 0, 95000.0, 0.0, 'K0008')
# ('GI0000464', 'KERAMIK 30 X 60 ROMAN GT 635513 R', 0, 22500.0, 0.0, 'K0008')
# ('GI0000465', 'KERAMIK 30 X 60 ROMAN GT 632402 R', 0, 0.0, 0.0, 'K0008')
# ('GI0000466', 'KERAMIK 30 X 60 ROMAN GT 635512 R', 0, 0.0, 0.0, 'K0008')
# ('GI0000467', 'KERAMIK 30 X 60 NIRO GSV 02 VEINSTONE BROWN ', 0, 22500.0, 0.0, 'K0008')
# ('GI0000468', 'KERAMIK 30 X 60 NIRO GSV 02SS (BLACK) ', 0, 0.0, 0.0, 'K0008')
# ('GI0000469', 'KERAMIK 30 X 60 NIRO GS 041 SS', 0, 135000.0, 0.0, 'K0008')
# ('GI0000470', 'KERAMIK 30 X 60 NIRO GIP 04', 0, 0.0, 0.0, 'K0008')
# ('GI0000471', 'KERAMIK 20 X 33 IKAD ALMOND DARK BROWN (POLOS) AEMU2', 0, 72500.0, 0.0, 'K0009')
# ('GI0000472', 'KERAMIK 25 X 40 MULIA BRINA GREY IMU3', 0, 60000.0, 0.0, 'K0006')
# ('GI0000473', 'KERAMIK 25 X 40 MULIA BRINA BEIGE IMU3', 0, 60000.0, 0.0, 'K0006')
# ('GI0000474', 'KERAMIK 25 X 40 MULIA MAGELANG PINK  ITMU2', 0, 60000.0, 0.0, 'K0006')
# ('GI0000475', 'KERAMIK 25 X 40 MULIA VINTAGE BEIGE IAU3', 0, 60000.0, 0.0, 'K0006')
# ('GI0000476', 'KERAMIK 25 X 40 MULIA AUDY GRIGIO IAU3', 0, 60000.0, 0.0, 'K0006')
# ('GI0000477', 'KERAMIK 25 X 40 MULIA SEBATIK GREEN IAMU2', 0, 65000.0, 0.0, 'K0006')
# ('GI0000478', 'KERAMIK 25 X 40 MULIA SEBATIK BEIGO IAMU2', 0, 65000.0, 0.0, 'K0006')
# ('GI0000479', 'KERAMIK 25 X 40 MULIA SEBATIK PINK IAMU2', 0, 65000.0, 0.0, 'K0006')
# ('GI0000480', 'KERAMIK 25 X 40 MULIA SEBATIK BLUE IAMU2', 0, 65000.0, 0.0, 'K0006')
# ('GI0000481', 'KERAMIK 25 X 40 MULIA LIVIGNO GOLD AMU3 ', 0, 75000.0, 0.0, 'K0006')
# ('GI0000482', 'KERAMIK 25 X 40 MULIA LIVIGNO DECO GOLD AOMU2', 0, 80000.0, 0.0, 'K0006')
# ('GI0000483', 'KERAMIK 25 X 40 ARWANA (UNO) SALUR BIRU 25427 MU4 ', 0, 65000.0, 0.0, 'K0006')
# ('GI0000484', 'KERAMIK 25 X 40 ARWANA BEIGE 25418 MU4', 0, 65000.0, 0.0, 'K0006')
# ('GI0000485', 'KERAMIK 25 X 40 ASTON TULIP LILAC IU4', 0, 60000.0, 0.0, 'K0006')
# ('GI0000486', 'KERAMIK 25 X 40 PICASSO LINEA LIGHT PINK ', 0, 0.0, 0.0, 'K0006')
# ('GI0000487', 'KERAMIK 20 X 40 CENTRINO LOVINA GREY OU4', 0, 95000.0, 0.0, 'K0026')
# ('GI0000488', 'KERAMIK 20 X 40 CENTRINO LOVINA CREAM OEU3', 0, 95000.0, 0.0, 'K0026')
# ('GI0000489', 'KERAMIK 20 X 40 CENTRINO KUTA GREY DDU3', 0, 95000.0, 0.0, 'K0026')
# ('GI0000490', 'KERAMIK 20 X 40 CENTRINO LOVINA KUTA BLACK DDU3  ', 0, 95000.0, 0.0, 'K0026')
# ('GI0000491', 'KERAMIK 20 X 40 CENTRINO LEGIAN GREY DDU3', 0, 95000.0, 0.0, 'K0026')
# ('GI0000492', 'KERAMIK 20 X 40 CENTRINO JIMBARAN GREY DDU3', 0, 95000.0, 0.0, 'K0026')
# ('GI0000493', 'KERAMIK 20 X 25 MULIA PUTIH ITU3', 0, 55000.0, 0.0, 'K0025')
# ('GI0000494', 'KERAMIK 20 X 25 MULIA PASTEL BLUE ITMU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000495', 'KERAMIK 20 X 25 MULIA PASTEL PINK ITMU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000496', 'KERAMIK 20 X 25 MULIA PASTEL BISCUIT ITMU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000497', 'KERAMIK 20 X 25 DIAMOND HIJAU POLOS ITMU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000498', 'KERAMIK 20 X 25 MULIA ALPEN BEIGE IUEU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000499', 'KERAMIK 20 X 25 MULIA ALPEN BLUE IUEU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000500', 'KERAMIK 20 X 25 MULIA ALPEN PINK IUEU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000501', 'KERAMIK 20 X 25 MULIA ALPEN GREEN IUEU2', 0, 55000.0, 0.0, 'K0025')
# ('GI0000503', 'KERAMIK 20 X 25 MULIA NAPOLI VERDE IEU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000504', 'KERAMIK 20 X 25 MULIA MAGNOVA BEIGE ITU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000505', 'KERAMIK 20 X 25 MULIA GUPY BEIGE ITMU2', 0, 52500.0, 0.0, 'K0025')
# ('GI0000506', 'KERAMIK 20 X 25 MULIA GUPY BLUE ITMU2', 0, 52500.0, 0.0, 'K0025')
# ('GI0000507', 'KERAMIK 20 X 25 MULIA GUPY PINK ITMU2', 0, 52500.0, 0.0, 'K0025')
# ('GI0000508', 'KERAMIK 20 X 25 MULIA GUPY GREEN ITMU2', 0, 52500.0, 0.0, 'K0025')
# ('GI0000509', 'KERAMIK 20 X 25 MULIA VENTURA BEIGE IRU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000510', 'KERAMIK 20 X 25 MULIA VENTURA BLUE IRU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000511', 'KERAMIK 20 X 25 MULIA VENTURA GREEN IRU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000512', 'KERAMIK 20 X 25 MULIA NAPOLI GRIGIO IEU3', 0, 57500.0, 0.0, 'K0025')
# ('GI0000513', 'KERAMIK 20 X 25 GARUDA BOBY DARK GREEN MU4 ', 0, 60000.0, 0.0, 'K0025')
# ('GI0000514', 'KERAMIK 20 X 25 GARUDA BOBY DARK RED MEMU2', 0, 65000.0, 0.0, 'K0025')
# ('GI0000515', 'KERAMIK 20 X 25 GARUDA BOBY DARK CREAM MU4 ', 0, 60000.0, 0.0, 'K0025')
# ('GI0000516', 'KERAMIK 20 X 25 ASIA NEPAL ROD IOU3', 0, 60000.0, 0.0, 'K0025')
# ('GI0000517', 'KERAMIK 20 X 25 ASIA ZOLA RED ROMU2', 0, 52000.0, 0.0, 'K0025')
# ('GI0000518', 'KERAMIK 20 X 25 ASIA ZOLA BROWN ROMU2', 0, 52000.0, 0.0, 'K0025')
# ('GI0000519', 'KERAMIK 20 X 25 ASIA ZOLA BLUE ROMU2', 0, 52000.0, 0.0, 'K0025')
# ('GI0000520', 'KERAMIK 20 X 25 ASIA MONTANA DARK GREEN IOU3', 0, 58000.0, 0.0, 'K0025')
# ('GI0000521', 'KERAMIK 20 X 25 ASIA MONTANA DARK RED IOU3 ', 0, 58000.0, 0.0, 'K0025')
# ('GI0000522', 'KERAMIK 20 X 25 ASIA MONTANA DARK BROWN IOU3 ', 0, 58000.0, 0.0, 'K0025')
# ('GI0000523', 'KERAMIK 20 X 25 ASIA ZARA BROWN ITMU2 ', 0, 52000.0, 0.0, 'K0025')
# ('GI0000524', 'KERAMIK 20 X 25 ASIA ZARA BLUE ITMU2', 0, 52000.0, 0.0, 'K0025')
# ('GI0000525', 'KERAMIK 20 X 25 IKAD LILY HITAM 3719 ', 0, 67500.0, 0.0, 'K0025')
# ('GI0000526', 'KERAMIK 20 X 25 IKAD LILY HITAM ( 1 DUS = 1,5 CM) DDMU2', 0, 100000.0, 0.0, 'K0025')
# ('GI0000527', 'KERAMIK 20 X 25 IKAD KEMBANG BIRU TUA DDMU2 ', 0, 100000.0, 0.0, 'K0025')
# ('GI0000528', 'KERAMIK 30 X 30 MULIA PUTIH 36000 RMDMU ', 0, 42500.0, 0.0, 'K0027')
# ('GI0000529', 'KERAMIK 30 X 30 ASIA PUTIH (MURANO) 35000 RTU3', 0, 40000.0, 0.0, 'K0027')
# ('GI0000530', 'KERAMIK 30 X 30 IKAD GE 7415 ABU ITMU2', 0, 55000.0, 0.0, 'K0027')
# ('GI0000531', 'KERAMIK 30 X 30 IKAD GRANIT COKLAT 7521 IRMU2', 0, 55000.0, 0.0, 'K0027')
# ('GI0000532', 'KERAMIK 30 X 30 IKAD GRANIT HITAM 7721 IRMU2', 0, 55000.0, 0.0, 'K0027')
# ('GI0000533', 'KERAMIK 30 X 30 ASIA OSCAR GREY IAU3 ', 0, 57000.0, 0.0, 'K0027')
# ('GI0000534', 'KERAMIK 30 X 30 ASIA VOLARE CREAM ROU3', 0, 48000.0, 0.0, 'K0027')
# ('GI0000535', 'KERAMIK 30 X 30 ASIA VOLARE GREY ROU3', 0, 48000.0, 0.0, 'K0027')
# ('GI0000536', 'KERAMIK 30 X 30 ASIA CORSICA MARON IIMU2', 0, 55000.0, 0.0, 'K0027')
# ('GI0000537', 'KERAMIK 30 X 30 MULIA SANASTONE BEIGE IIU3', 0, 55000.0, 0.0, 'K0027')
# ('GI0000538', 'KERAMIK 30 X 30 MULIA ATILA TERAKOTA ITU3', 0, 52500.0, 0.0, 'K0027')
# ('GI0000539', 'KERAMIK 30 X 30 DK GRANITI GREEN (DK) IRMU2', 0, 57500.0, 0.0, 'K0027')
# ('GI0000540', 'KERAMIK 30 X 30 DK GRANIT RED(DK) IRMU2', 0, 57500.0, 0.0, 'K0027')
# ('GI0000541', 'KERAMIK 50 X 50 IKAD BEIGE 2243 ATMU2 ', 0, 65000.0, 0.0, 'K0014')
# ('GI0000542', 'KERAMIK 50 X 50 IKAD CLEOPATRA BEIGE IOU3', 0, 65000.0, 0.0, 'K0014')
# ('GI0000543', 'KERAMIK 50 X 50 IKAD CLEOPATRA ABU ATMU2', 0, 65000.0, 0.0, 'K0014')
# ('GI0000544', 'KERAMIK 50 X 50 IKAD PUTIN 2166 ATMU2 ', 0, 75000.0, 0.0, 'K0014')
# ('GI0000545', 'KERAMIK 50 X 50 IKAD SALUR BROWN 7583 ATMU2', 0, 75000.0, 0.0, 'K0014')
# ('GI0000546', 'KERAMIK 50 X 50 IKAD 8581 AMMU2', 0, 90000.0, 0.0, 'K0014')
# ('GI0000547', 'KERAMIK 50 X 50 IKAD BATU ABU 7482 ATMU2 ', 0, 75000.0, 0.0, 'K0014')
# ('GI0000548', 'KERAMIK 50 X 50 IKAD ROSELYNN 2242 ATMU2', 0, 75000.0, 0.0, 'K0014')
# ('GI0000549', 'KERAMIK 50 X 50 SUN POWER ALEXA GREEN LOOU MTU3  ', 0, 67500.0, 0.0, 'K0014')
# ('GI0000550', 'KERAMIK 50 X 50 SUN POWER OSAKA GREY NOO5 MTU3', 0, 67500.0, 0.0, 'K0014')
# ('GI0000551', 'KERAMIK 50 X 50 SUN POWER OSAKA BEIGE NOO7 MTU3', 0, 67500.0, 0.0, 'K0014')
# ('GI0000552', 'KERAMIK 50 X 50 SUN POWER HITAM POLOS HT 5999 ADMU2', 0, 87500.0, 0.0, 'K0014')
# ('GI0000553', 'KERAMIK 50 X 50 CONCORDE STING WOOD BROWN AEU3', 0, 85000.0, 0.0, 'K0014')
# ('GI0000554', 'KERAMIK 50 X 50 CONCORDE STING WOOD CREAM  AEU3', 0, 85000.0, 0.0, 'K0014')
# ('GI0000555', 'KERAMIK 50 X 50 KOBIN BEAUTY BLACK', 0, 0.0, 0.0, 'K0014')
# ('GI0000556', 'Keramik 40 x 40 MULIA PUTIH RAU3 ', 0, 45000.0, 0.0, 'K0029')
# ('GI0000557', 'Keramik 40 x 40 MULIA HITAM MU4', 0, 60000.0, 0.0, 'K0029')
# ('GI0000558', 'Keramik 40 x 40 IKAD PUTIH RIU3', 0, 45000.0, 0.0, 'K0029')
# ('GI0000559', 'Keramik 40 x 40 IKAD HITAM MIMU2', 0, 65000.0, 0.0, 'K0029')
# ('GI0000560', 'Keramik 40 x 40 IKAD STRATA PUTIH RAWU2', 0, 47500.0, 0.0, 'K0029')
# ('GI0000561', 'Keramik 40 x 40 IKAD GALAXY GREY IU4', 0, 50000.0, 0.0, 'K0029')
# ('GI0000562', 'Keramik 40 x 40 IKAD PETIR PINK 1859 IDMU2 ', 0, 57500.0, 0.0, 'K0029')
# ('GI0000563', 'Keramik 40 x 40 IKAD PETIR HIJAU 1359 IDMU2', 0, 57500.0, 0.0, 'K0029')
# ('GI0000564', 'Keramik 40 x 40 IKAD PETIR BEIGE 1559 IDMU2', 0, 57500.0, 0.0, 'K0029')
# ('GI0000565', 'Keramik 40 x 40 IKAD BATU ABU S X 8451 MIMU2', 0, 70000.0, 0.0, 'K0029')
# ('GI0000566', 'Keramik 40 x 40 IKAD GRANIT PUTIH 2117 MRU3', 0, 65000.0, 0.0, 'K0029')
# ('GI0000567', 'Keramik 40 x 40 IKAD GRANIT HITAM 3717 MEMU2 ', 0, 65000.0, 0.0, 'K0029')
# ('GI0000568', 'Keramik 40 x 40 IKAD SERAT KAYU SX 6246 IKMU2', 0, 60000.0, 0.0, 'K0029')
# ('GI0000569', 'Keramik 40 x 40 IKEMA THUNDER BEIGE IAMU2 ', 0, 57000.0, 0.0, 'K0029')
# ('GI0000570', 'Keramik 40 x 40 IKEMA THUNDER HIJAU 1376 IAMU2', 0, 57000.0, 0.0, 'K0029')
# ('GI0000571', 'Keramik 40 x 40 MULIA SANDSTONE BEIGE  ', 0, 57500.0, 0.0, 'K0029')
# ('GI0000572', 'Keramik 40 x 40 MULIA TEXAS TAUPE RMMU2  ', 0, 47500.0, 0.0, 'K0029')
# ('GI0000573', 'Keramik 40 x 40 MULIA LOMPOC GREEN RMMU2', 0, 47500.0, 0.0, 'K0029')
# ('GI0000574', 'Keramik 40 x 40 MULIA ZEITA BEIGE RIU3', 0, 47500.0, 0.0, 'K0029')
# ('GI0000575', 'Keramik 40 x 40 MULIA ZEITA GREY RIU3', 0, 47500.0, 0.0, 'K0029')
# ('GI0000576', 'Keramik 40 x 40 MULIA YOSEMITE BEIGE ROU3 ', 0, 47500.0, 0.0, 'K0029')
# ('GI0000577', 'Keramik 40 x 40 MULIA BENOA RUST IMU3', 0, 60000.0, 0.0, 'K0029')
# ('GI0000578', 'Keramik 40 x 40 MULIA GLACIER SAND IMU3 ', 0, 60000.0, 0.0, 'K0029')
# ('GI0000579', 'Keramik 40 x 40 MULIA CALIFORNIA WOOD BEIGE RAU3 ', 0, 48000.0, 0.0, 'K0029')
# ('GI0000580', 'Keramik 40 x 40 MULIA CALIFORNIA GREY RAU3 ', 0, 48000.0, 0.0, 'K0029')
# ('GI0000581', 'Keramik 40 x 40 MULIA SACRAMENTO BEIGE ROU3 ', 0, 50000.0, 0.0, 'K0029')
# ('GI0000582', 'Keramik 40 x 40 MULIA SACRAMENTO GREY ROU3', 0, 50000.0, 0.0, 'K0029')
# ...
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000795',
#   'Dulux V-gloss Pewter Grey 40698 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000796',
#   'Dulux V-gloss Old Coral 43633 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000797',
#   'Dulux V-gloss Mustard Banana 45588* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000798',
#   'Dulux V-gloss Turquoise 42619 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000799',
#   'Dulux V-gloss Oriental Blue 41672* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000800',
#   'Dulux V-gloss Jade Dove 40699 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000801',
#   'Dulux V-gloss Symphony Pink 43632* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000802',
#   'Dulux V-gloss Lily Yellow 45586* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000803',
#   'Dulux V-gloss Victoria Garden 42621 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000804',
#   'Dulux V-gloss Neptune Navy 41673 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000805',
#   'Dulux V-gloss Dolphin Grey 40700 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000806',
#   'Dulux V-gloss Papillon Red 43631 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000807',
#   'Dulux V-gloss Sweet Melon 47526 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000808',
#   'Dulux V-gloss Aspen Green 42622 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000809',
#   'Dulux V-gloss Aspen Green 42622 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000810',
#   'Dulux V-gloss Saphire Blue 41671* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000811',
#   'Dulux V-gloss Moca Rich 46635 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000812',
#   'Dulux V-gloss Vermillon 43630* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000813',
#   'Dulux V-gloss Pumpkin Orange 47527* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000814',
#   'Dulux V-gloss Eden Green 42623 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000815',
#   'Dulux V-gloss Blue Night 41674* (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000816', 'Dulux V-gloss Black 122 (0,8Ltr) ', 0, 55000.0, 0.0, 'K0021'),
#  ('GI0000817',
#   'Dulux V-gloss Spicy Brown 46634 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000818',
#   'Dulux V-gloss Bamboo Cream 46628 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000819',
#   'Dulux V-gloss Adeline Pearl 46629 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000820',
#   'Dulux V-gloss Papirus Iced 46626 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000821',
#   'Dulux V-gloss Butterfly 46627 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000822',
#   'Dulux V-gloss Brown Leather 46631(0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000823',
#   'Dulux V-gloss Earthland 46637(0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000824',
#   'Dulux V-gloss Cinnamon Suede 46630 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000825',
#   'Dulux V-gloss Candy Honey 46636 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000826',
#   'Dulux V-gloss Dust Brown 46633 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000827',
#   'Dulux V-gloss White Doff 9002 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000828',
#   'Dulux V-gloss Dust Brown Doff 46651(0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000829',
#   'Dulux V-gloss Butterfly Doff 46639 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000830',
#   'Dulux V-gloss Paper Grey Doff 40707 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000831',
#   'Dulux V-gloss Cinnamon Suede Doff 46652 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000832',
#   'Dulux V-gloss Adeline Pearl Doff 46650 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000833',
#   'Dulux V-gloss Balck Doff 40710 (0,8Ltr)',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000834',
#   'Dulux V-gloss Brown Leather Doff 46653(0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000835',
#   'Dulux V-gloss Papirus iced Doff 46654 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000836',
#   'Dulux V-gloss Loud Stone Doff 40708 (0,8Ltr) ',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000837',
#   'Dulux V-gloss Spruce Doff 42438 (0,8Ltr)',
#   0,
#   55000.0,
#   0.0,
#   'K0021'),
#  ('GI0000838',
#   'Dulux Pentalite Ceiling-A923-108 (5Kg) ',
#   0,
#   120000.0,
#   0.0,
#   'K0021'),
#  ('GI0000839',
#   'Dulux Roof Paint Mission Brown 46503 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000840',
#   'Dulux Roof Paint Dark Brown 46047 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000841',
#   'Dulux Roof Paint Dark Grey 40504 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000842',
#   'Dulux Roof Paint Lido 42506 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000843',
#   'Dulux Roof Paint Red Oxide 43031 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000844',
#   'Dulux Roof Paint Forest Green 42502 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000845',
#   'Dulux Roof Paint Leaf Green 42501 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000846',
#   'Dulux Roof Paint Terracotta 43044 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000847',
#   'Dulux Roof Paint Orange 43505 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000848',
#   'Dulux Roof Paint Casa Blue 41373 (2,5Ltr)',
#   0,
#   168000.0,
#   0.0,
#   'K0021'),
#  ('GI0000849', 'LEMKRA FS NAT 202 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000850', 'LEMKRA FS NAT 203 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000851', 'LEMKRA FS NAT 204 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000852', 'LEMKRA FS NAT 205 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000853', 'LEMKRA FS NAT 206 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000854', 'LEMKRA FS NAT 207 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000855', 'LEMKRA FS NAT 208 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000856', 'LEMKRA FS NAT 209 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000857', 'LEMKRA FS NAT 210 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000858', 'LEMKRA FS NAT 211 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000859', 'LEMKRA FS NAT 212 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000860', 'LEMKRA FS NAT 213 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000861', 'LEMKRA FS NAT 214 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000862', 'LEMKRA FS NAT 215 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000863', 'LEMKRA FS NAT 216 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000864', 'LEMKRA FS NAT 217 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000865', 'LEMKRA FS NAT 218 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000866', 'LEMKRA FS NAT 219 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000867', 'LEMKRA FS NAT 220 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000868', 'LEMKRA FS NAT 221 1KG ', 0, 19500.0, 0.0, 'K0019'),
#  ('GI0000869', 'SIKA NAT GREY 261 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000870', 'SIKA NAT IVORY 265 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000871', 'SIKA NAT PINK 269 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000872', 'SIKA NAT LIGHT GREEN 262 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000873', 'SIKA NAT YELLOW 258 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000874', 'SIKA NAT CREAM 263 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000875', 'SIKA NAT MEDITERANIA 271 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000876', 'SIKA NAT GREEN 259 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000877', 'SIKA NAT BLUE 264 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000878', 'SIKA NAT RED 257 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000879', 'SIKA NAT BLACK 260 1KG ', 0, 12500.0, 0.0, 'K0018'),
#  ('GI0000880',
#   'Cat Dasar Catylac Interior-A931-49300 (4Kg)   ',
#   0,
#   102000.0,
#   0.0,
#   'K0022'),
#  ('GI0000881',
#   'Cat Dasar Catylac Interior-A931-49300 (21Kg) ',
#   0,
#   519000.0,
#   0.0,
#   'K0023'),
#  ('GI0000882',
#   'Plamur Catylac Interior-A931-49501 (5Kg) ',
#   0,
#   57000.0,
#   0.0,
#   'K0022'),
#  ('GI0000883',
#   'Plamur Catylac Interior-A931-49501 (25Kg)',
#   0,
#   279000.0,
#   0.0,
#   'K0023'),
#  ('GI0000884', 'Thinner Dulux-A850-41 (1Ltr) ', 0, 28000.0, 0.0, 'K0021'),
#  ('GI0000885',
#   'Cat Dasar Dulux Alkali Resisting Interior-A931-1050N (2,5Ltr)  ',
#   0,
#   121000.0,
#   0.0,
#   'K0021'),
#  ('GI0000886',
#   'Cat Dasar Dulux Alkali Resisting Interior-A931-1050N (20Ltr) ',
#   0,
#   865000.0,
#   0.0,
#   'K0021'),
#  ('GI0000887',
#   'Cat Dasar Weathersheild Primer-A931-49100 (2,5Ltr) ',
#   0,
#   127000.0,
#   0.0,
#   'K0021'),
#  ('GI0000888',
#   'Cat Dasar Weathersheild Primer-A931-49100 (20Ltr) ',
#   0,
#   921000.0,
#   0.0,
#   'K0021'),
#  ('GI0000889',
#   'Dulux WS Putty-A931-49200 (3,5Kg) ',
#   0,
#   102000.0,
#   0.0,
#   'K0021'),
#  ('GI0000890',
#   'Dulux Alkali Killer Solvent Base Primer Sealer-A579-44469 (2,5Ltr) ',
#   0,
#   148000.0,
#   0.0,
#   'K0021'),
#  ('GI0000891',
#   'Dulux Pentalite Ceiling-A923-108 (25Kg)',
#   0,
#   570000.0,
#   0.0,
#   'K0021'),
#  ('GI0000892',
#   'Dulux Weathershield Pro Rock Rose 43346* (2,5Ltr) \t',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000893',
#   'Dulux Weathershield Pro Crystal Peach 47326 (2,5Ltr) ',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000894',
#   'Dulux Weathershield Pro Palazzo 47314 (2,5Ltr)\t',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000895',
#   'Dulux Weathershield Pro Fruity Yellow 45379* (2,5Ltr)\t ',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000896',
#   'Dulux Weathershield Pro Sunny Havana 45409* (2,5Ltr)\t ',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000897',
#   'Dulux Weathershield Pro Renada 42394* (2,5Ltr)\t ',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000898',
#   'Dulux Weathershield Pro Basilica 47317 (2,5Ltr)\t\t',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000899',
#   'Dulux Weathershield Pro Jamaican 45413* (2,5Ltr)\t ',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000900',
#   'Dulux Weathershield Pro Yellow Bird 45387 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000901',
#   'Dulux Weathershield Pro Volcanic Splash 47341* (2,5Ltr)\t ',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000902',
#   'Dulux Weathershield Pro Frosted Lime 45380 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000903',
#   'Dulux Weathershield Pro Country Blue 41387 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000904',
#   'Dulux Weathershield Pro Day Break 40544M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000905',
#   'Dulux Weathershield Pro Brilliant White 2290M (2,5Ltr)',
#   0,
#   242000.0,
#   0.0,
#   'K0021'),
#  ('GI0000906',
#   'Dulux Weathershield Pro Holiday Blues 44405 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000907',
#   'Dulux Weathershield Pro Dove 40140M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000908',
#   'Dulux Weathershield Pro Lakestone 44537M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000909',
#   'Dulux Weathershield Pro Verandah 42368* (2,5Ltr)',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000910',
#   'Dulux Weathershield Pro Blue Beauty 41388* (2,5Ltr)\t ',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000911',
#   'Dulux Weathershield Pro Mirage 44012M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000912',
#   'Dulux Weathershield Pro Platinum Grey 40351 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000913',
#   'Dulux Weathershield Pro Galant Grey 40545M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000914',
#   'Dulux Weathershield Pro Palm Tree Green 42384 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000915',
#   'Dulux Weathershield Pro Merlin 40156M* (2,5Ltr)',
#   0,
#   279000.0,
#   0.0,
#   'K0021'),
#  ('GI0000916',
#   'Dulux Weathershield Pro Cement 42164M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000917',
#   'Dulux Weathershield Pro Butternut 44540M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000918',
#   'Dulux Weathershield Pro Macadamia 44541M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000919',
#   'Dulux Weathershield Pro Carrara 44441 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000920',
#   'Dulux Weathershield Pro Morning Star 44539M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000921',
#   'Dulux Weathershield Pro Butter Cup 45410 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000922',
#   'Dulux Weathershield Pro Brownstone 46649M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000923',
#   'Dulux Weathershield Pro Teratai 44011M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000924',
#   'Dulux Weathershield Pro Ruby Sand 44518 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000925',
#   'Dulux Weathershield Pro Sagoo 44138M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000926',
#   'Dulux Weathershield Pro Liberty 46395 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000927',
#   'Dulux Weathershield Pro Carita 46017M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000928',
#   'Dulux Weathershield Pro Ruffles Marine 44565M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000929',
#   'Dulux Weathershield Pro Cheese Crust 45411 (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000930',
#   'Dulux Weathershield Pro Sandstone 46137M (2,5Ltr)',
#   0,
#   250000.0,
#   0.0,
#   'K0021'),
#  ('GI0000931',
#   'Cat Dasar Catylac Exterior-A931-49400 (4Kg) ',
#   0,
#   111500.0,
#   0.0,
#   'K0022'),
#  ('GI0000932',
#   'Cat Dasar Catylac Exterior-A931-49400 (21Kg)',
#   0,
#   568000.0,
#   0.0,
#   'K0023'),
#  ('GI0000933', 'Torn Tirta T500PK (D950;T1.216) ', 0, 1932000.0, 0.0, 'K0015'),
#  ('GI0000934',
#   'Torn Tirta T1.000PK (D950;T1.240) ',
#   0,
#   2625000.0,
#   0.0,
#   'K0015'),
#  ('GI0000935',
#   'Torn Tirta T1.200PK (D950;T1.440) ',
#   0,
#   2845000.0,
#   0.0,
#   'K0015'),
#  ('GI0000936',
#   'Torn Tirta T1.500PK (D950;T1.740) ',
#   0,
#   3276000.0,
#   0.0,
#   'K0015'),
#  ('GI0000937',
#   'Torn Tirta T1.800PK (D950;T2.040) ',
#   0,
#   3706500.0,
#   0.0,
#   'K0015'),
#  ('GI0000938',
#   'Torn Tirta T2.000PK (D950;T2.240) ',
#   0,
#   4095000.0,
#   0.0,
#   'K0015'),
#  ('GI0000939',
#   'Torn Tirta T500TK (D950;T1.1080) ',
#   0,
#   1816500.0,
#   0.0,
#   'K0015'),
#  ('GI0000940',
#   'Torn Tirta T1.000TK (D950;T1.120) ',
#   0,
#   2488500.0,
#   0.0,
#   'K0015'),
#  ('GI0000941',
#   'Torn Tirta T1.200TK (D950;T1.320) ',
#   0,
#   2646000.0,
#   0.0,
#   'K0015'),
#  ('GI0000942',
#   'Torn Tirta T1.500TK (D950;T1.620) \t\t',
#   0,
#   3171000.0,
#   0.0,
#   'K0015'),
#  ('GI0000943',
#   'Torn Tirta T1.800TK (D950;T1.920) \t',
#   0,
#   3475500.0,
#   0.0,
#   'K0015'),
#  ('GI0000944',
#   'Torn Penguin TB32-300ltr (D690;T870) ',
#   0,
#   950000.0,
#   0.0,
#   'K0015'),
#  ('GI0000945',
#   'Torn Penguin TB33-300ltr (D690;T870)          ',
#   0,
#   950000.0,
#   0.0,
#   'K0015'),
#  ('GI0000946',
#   'Torn Penguin TB53-520ltr (D830;T1.110)         ',
#   0,
#   1500000.0,
#   0.0,
#   'K0015'),
#  ('GI0000947',
#   'Torn Penguin TB55-520ltr (D830;T1.110)         ',
#   0,
#   1500000.0,
#   0.0,
#   'K0015'),
#  ('GI0000948',
#   'Torn Penguin TB70-650ltr (D880;T1.285)         ',
#   0,
#   1700000.0,
#   0.0,
#   'K0015'),
#  ('GI0000949',
#   'Torn Penguin TB80-800ltr (D830;T1.700)          ',
#   0,
#   2100000.0,
#   0.0,
#   'K0015'),
#  ('GI0000950',
#   'Torn Penguin TB110-1.050ltr (D1.050;T1.340)          ',
#   0,
#   2500000.0,
#   0.0,
#   'K0015'),
#  ('GI0000951',
#   'Torn Penguin TB200-2.000ltr (D1.440;T1.505)          ',
#   0,
#   4800000.0,
#   0.0,
#   'K0015'),
#  ('GI0000952',
#   'Toren Penyu TS25-225Ltr (D61;T90)\t',
#   0,
#   654500.0,
#   0.0,
#   'K0015'),
#  ('GI0000953',
#   'Toren Penyu TS32-320Ltr (D68;T90)\t',
#   0,
#   764500.0,
#   0.0,
#   'K0015'),
#  ('GI0000954',
#   'Toren Penyu TS55-570Ltr (D86;T116)\t',
#   0,
#   1179500.0,
#   0.0,
#   'K0015'),
#  ('GI0000955',
#   'Toren Penyu TS72-720Ltr (D87;T127)\t',
#   0,
#   1435000.0,
#   0.0,
#   'K0015'),
#  ('GI0000956',
#   'Toren Penyu TS80-840Ltr (D98;T128)\t',
#   0,
#   1595000.0,
#   0.0,
#   'K0015'),
#  ('GI0000957',
#   'Toren Penyu TS110-1.200Ltr (D112;T140)\t',
#   0,
#   1995000.0,
#   0.0,
#   'K0015'),
#  ('GI0000958',
#   'Toren Penyu TS200-2.200Ltr (D142;T156)\t',
#   0,
#   3885000.0,
#   0.0,
#   'K0015'),
#  ('GI0000959',
#   'Toren Penyu TS300-3.300Ltr (D164;T180)\t',
#   0,
#   5755000.0,
#   0.0,
#   'K0015'),
#  ('GI0000960',
#   'Toren Penyu TS500-5.500Ltr (D187;T238)\t',
#   0,
#   9385000.0,
#   0.0,
#   'K0015'),
#  ('GI0000961',
#   'Toren Penyu TS1.100-10.500Ltr (D225;T324)\t',
#   0,
#   20965000.0,
#   0.0,
#   'K0015'),
#  ('GI0000962', 'Toren Grand Luxe 600Ltr ', 0, 805000.0, 0.0, 'K0015'),
#  ('test', 'test', 0, 0.0, 0.0, '0')]

# %% [markdown]
# # edit barang

# %%
import mysql.connector

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="all_barang"
)

mycursor = mydb.cursor()
mycursor.execute("SELECT * FROM barang")
myresult = mycursor.fetchall()

for x in myresult:
  print(x)

id = myresult[0][0]


myresult
